# %% [markdown]
# <table border=0 width="100%"><tr><td><p align="left"><img src="..\img\logo-1.jpg" align="left" width=300></p></td><td><font size=3><B>Data analysis (Python) - homework in week 7</B></font></td></tr></table>

# %% [markdown]
# tips
# - rename the name jupyter notebook file following the rules: **replace ID and name with your student ID and your own name**

# %%
name = input("what is your name: ")
# Out:
# what is your name: 1

# %%
student_ID = input("what is your student ID: ")
# Out:
# what is your student ID: 1

# %% [markdown]
# ## part 1 (50 points)

# %% [markdown]
# download IMDB comments whoes rating is 1 using BeautifulSoup, and save the comments in a list comments
#
# tips -
# - url = "https://www.imdb.com/title/tt0110912/reviews"
# - para = {"ratingFilter":"1"}

# %%
url = "https://www.imdb.com/title/tt0110912/reviews"
para = {"ratingFilter":"1"}
comments = []
# please start work here

# %%
def download_page(url,para=None):
    header={"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.131 Safari/537.36"}
    if para:
        response=requests.get(url,params=para,headers=header)
    else:
        response=requests.get(url,headers=hearder)
    response.encoding=response.apparent_encoding
    if response.status_code==200:
        return response.text
    else:
        return None

# %%
import requests
url = "https://www.imdb.com/title/tt0110912/reviews"
para = {"ratingFilter":"1"}
comments = []
# please start work here
html = download_page(url,para)

# %%
from bs4 import BeautifulSoup

# %%
soup=BeautifulSoup(html)
soup
# Out:
# <!DOCTYPE html>
# <html xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
# <head>
# <script type="text/javascript">var ue_t0=ue_t0||+new Date();</script>
# <script type="text/javascript">
# window.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;
# if (window.ue_ihb === 1) {
#
# var ue_csm = window,
#     ue_hob = +new Date();
# (function(d){var e=d.ue=d.ue||{},f=Date.now||function(){return+new Date};e.d=function(b){return f()-(b?0:d.ue_t0)};e.stub=function(b,a){if(!b[a]){var c=[];b[a]=function(){c.push([c.slice.call(arguments),e.d(),d.ue_id])};b[a].replay=function(b){for(var a;a=c.shift();)b(a[0],a[1],a[2])};b[a].isStub=1}};e.exec=function(b,a){return function(){try{return b.apply(this,arguments)}catch(c){ueLogError(c,{attribution:a||"undefined",logLevel:"WARN"})}}}})(ue_csm);
#
#
#     var ue_err_chan = 'jserr';
# ...

# %%
all_divs=soup.find_all("div",{"class":"text show-more__control"})
all_divs
# Out:
# [<div class="text show-more__control">The hugely overrated trivial chatting, the grotesque violence, the moral vacuum, the deadly slowness, the length --- about an hour too long --- make it incomprehensible today how this picture ever made people rave the way they did on this board.<br/><br/>The greatest film ever? Excuse me, this is a feature film that says nothing, depicts no authentic feelings or character development, is grossly self-indulgent and filled with idiotically implausible situations, such as people firing powerful handguns repeatedly, simultaneously and then hanging around chatting as if nobody would ever report the firing and summon the law.<br/><br/>Perhaps the most implausible character of all is played by Mr Tarantino, who shouts at the two hoodlum killers as if they were playmates from school and complains that his wife will divorce him if she returns from work to find a car in the garage containing a man with his head blown off.<br/><br/>Where is the moral compas
# ...

# %%
comments =[div.text for div in all_divs]

# %%
comments
# Out:
# ['The hugely overrated trivial chatting, the grotesque violence, the moral vacuum, the deadly slowness, the length --- about an hour too long --- make it incomprehensible today how this picture ever made people rave the way they did on this board.The greatest film ever? Excuse me, this is a feature film that says nothing, depicts no authentic feelings or character development, is grossly self-indulgent and filled with idiotically implausible situations, such as people firing powerful handguns repeatedly, simultaneously and then hanging around chatting as if nobody would ever report the firing and summon the law.Perhaps the most implausible character of all is played by Mr Tarantino, who shouts at the two hoodlum killers as if they were playmates from school and complains that his wife will divorce him if she returns from work to find a car in the garage containing a man with his head blown off.Where is the moral compass of the people who revere this schoolboy nonsense? Nobody in the 
# ...

# %%
import re
sens = [re.sub(r"\"",'',s) for s in comments]
sens
# Out:
# ["The hugely overrated trivial chatting, the grotesque violence, the moral vacuum, the deadly slowness, the length --- about an hour too long --- make it incomprehensible today how this picture ever made people rave the way they did on this board.The greatest film ever? Excuse me, this is a feature film that says nothing, depicts no authentic feelings or character development, is grossly self-indulgent and filled with idiotically implausible situations, such as people firing powerful handguns repeatedly, simultaneously and then hanging around chatting as if nobody would ever report the firing and summon the law.Perhaps the most implausible character of all is played by Mr Tarantino, who shouts at the two hoodlum killers as if they were playmates from school and complains that his wife will divorce him if she returns from work to find a car in the garage containing a man with his head blown off.Where is the moral compass of the people who revere this schoolboy nonsense? Nobody in the 
# ...

# %%
import re
data="sss\ss\ttt\s"
data=re.sub('[\u005c\]','',data) # \t 在python 有 含义，

# %%
data
# Out:
# 'sssss\ttts'

# %%
import re
data=r"sss\ss\ttt\s" ## r不转译
data=re.sub('[\u005c\]','',data) #

# %%
data
# Out:
# 'sssssttts'

# %% [markdown]
# <img src="..\img\WechatIMG415.jpg" align="left" width=1000>

# %%
text = "I love 🧸 so much!"

text = text.encode()
text = b"I love \xf0\x9f\xa7\xb8 so much!" #删除叹号，保留小熊编码

# %%
# text = re.sub(b"[^\w\s\\]", b"", text) # 报错

# %%
text = re.sub(b"[^\w\s\\\]", b"", text)
text
# Out:
# b'I love  so much'

# %%
import string

punc = string.punctuation.encode()

text = b"I love \xf0\x9f\xa7\xb8 so much!" 

clean_text = text.translate(None, punc)

# %%
clean_text
# Out:
# b'I love \xf0\x9f\xa7\xb8 so much'

# %% [markdown]
# ## part 2 (50 points)

# %% [markdown]
# read the paper titled "Diurnal and Seasonal Mood Vary with Work, Sleep, and Daylength Across Diverse Cultures"
#
# submit the a report with **word document in English** which covers the following points:
# * the topic of this paper
# * the data and process steps
# * main findings
