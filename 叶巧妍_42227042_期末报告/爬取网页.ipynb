# %%
import time
import requests
from bs4 import BeautifulSoup
import pandas as pd

url = "https://srh.bankofchina.com/search/whpj/search_cn.jsp"
headers = {'User-Agent':
'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/109.0.0.0 Safari/537.36 SLBrowser/9.0.0.10191 SLBChan/105'}

response = requests.post(url, headers = headers)
html = response.text
response.encoding = response.apparent_encoding
soup = BeautifulSoup(html, 'html.parser')
table = soup.find_all('table')[1]
rows = table.find('tr')
ths = rows.find_all('th')


rows

# %%
option_list = ['英镑']

for currency_option in option_list:
    for i in range(1, 13032):
        data = {
            'erectDate': '2023-12-09',
            'nothing': '2024-01-09',
            'pjname': currency_option,
            'page': '{}'.format(i),
            'head': 'head_620.js',
            'bottom': 'bottom_591.js'
        }
        response = requests.post(url, headers=headers, data=data)
        html = response.text
        response.encoding = response.apparent_encoding
     #   print(currency_option + "-" * 80)
        soup = BeautifulSoup(html, 'html.parser')
        table = soup.find_all('table')[1] 
        rows = table.find_all('tr')
        #ths = rows[0].find_all('th')
        df = pd.read_html(str(table))[0].iloc[:-1, :7]
        display(df)

# %%
import time
import pandas as pd
import requests
from bs4 import BeautifulSoup

result_df = pd.DataFrame()  # 创建空的DataFrame

for currency_option in option_list:
    for i in range(1, 2809):
        data = {
            'erectDate': '2023-01-09',
            'nothing': '2024-01-09',
            'pjname': '美元',
            'page': '{}'.format(i),
            'head': 'head_620.js',
            'bottom': 'bottom_591.js'
        }
        response = requests.post(url, headers=headers, data=data)
        html = response.text
        response.encoding = response.apparent_encoding
        soup = BeautifulSoup(html, 'html.parser')
        table = soup.find_all('table')[1]
        df = pd.read_html(str(table))[0].iloc[:-1, :7]
        result_df = result_df.append(df, ignore_index=True)  # 将数据追加到结果DataFrame
        display(df)

result_df.to_csv('result.csv', index=False)  # 保存结果DataFrame为CSV文件

# %%
result_df = pd.DataFrame()

# %%
for i in range(1, 351):
    data = {
            'erectDate': '2023-01-09',
            'nothing': '2023-02-16',
            'pjname': '美元',
            'page': '{}'.format(i),
            'head': 'head_620.js',
            'bottom': 'bottom_591.js'
        }
    response = requests.post(url, headers=headers, data=data)
    html = response.text
    response.encoding = response.apparent_encoding
    soup = BeautifulSoup(html, 'html.parser')
    table = soup.find_all('table')[1]
    df = pd.read_html(str(table))[0].iloc[:-1, :7]
    result_df = result_df.append(df, ignore_index=True)  # 将数据追加到结果DataFrame
    
result_df.to_csv('result.csv', index=False, mode='a')  # 保存结果DataFrame为CSV文件
